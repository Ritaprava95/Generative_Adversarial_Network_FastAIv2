# %%
from fastai.vision.all import *
from fastai.basics import *
from fastai.callback.all import *
from fastai.vision import gan
from fastai.vision.gan import *
import torch

# %%
dls = torch.load(r"../../data/train/GAN_dataloader.pkl")

# %%
dls.show_batch(max_n=4)

# %% [markdown]
# ## Making the learner

# %% [markdown]
# ### First I will train the model for just 2 epoch and see what the model generates

# %%
generator = basic_generator(64, n_channels=3, n_extra_layers=1)
critic = basic_critic(64, n_channels=3, n_extra_layers=1, act_cls=partial(nn.LeakyReLU, negative_slope=0.2))

# %%
learn = GANLearner.wgan(dls,
                        generator,
                        critic,
                        switcher=FixedGANSwitcher, # default: FixedGANSwitcher(n_crit:int=1, n_gen:int=1)
                        gen_first=False,
                        opt_func = RMSProp,
                        model_dir=r"E:\Work\Data_Science\Projects\Custom_GAN\models")

# %%
learn.recorder.train_metrics=True
learn.recorder.valid_metrics=False

# %%
learn.fit(2, 1e-4, wd=0.)
# Out:
# C:\Users\ritap\anaconda3\envs\fastaiv2\lib\site-packages\fastai\callback\core.py:72: UserWarning: You are shadowing an attribute (generator) that exists in the learner. Use `self.learn.generator` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# C:\Users\ritap\anaconda3\envs\fastaiv2\lib\site-packages\fastai\callback\core.py:72: UserWarning: You are shadowing an attribute (critic) that exists in the learner. Use `self.learn.critic` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# C:\Users\ritap\anaconda3\envs\fastaiv2\lib\site-packages\fastai\callback\core.py:72: UserWarning: You are shadowing an attribute (gen_mode) that exists in the learner. Use `self.learn.gen_mode` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>gen_loss</th>
#       <th>crit_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>-0.080702</td>
#       <td>0.227773</td>
#       <td>-0.335104</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>-0.151052</td>
#       <td>0.481270</td>
#       <td>-0.926093</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\ritap\anaconda3\envs\fastaiv2\lib\site-packages\fastprogress\fastprogress.py:73: UserWarning: Your generator is empty.
#   warn("Your generator is empty.")

# %%
learn.show_results(max_n=4, ds_idx=0)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ### As we can see that the generaed images still look pretty much like random noise

# %% [markdown]
# ### Now it's time to train this for longer epochs

# %%
generator = basic_generator(64, n_channels=3, n_extra_layers=1)
critic = basic_critic(64, n_channels=3, n_extra_layers=1, act_cls=partial(nn.LeakyReLU, negative_slope=0.2))

learn = GANLearner.wgan(dls,
                        generator,
                        critic,
                        switcher=FixedGANSwitcher, # default: FixedGANSwitcher(n_crit:int=1, n_gen:int=1)
                        gen_first=False,
                        opt_func = RMSProp,
                        show_img=True,
                        model_dir=r"E:\Work\Data_Science\Projects\Custom_GAN\models")

learn.recorder.train_metrics=True
learn.recorder.valid_metrics=False

# %%
learn.fit(25, 1e-4, wd=0.)
# Out:
# C:\Users\ritap\anaconda3\envs\fastaiv2\lib\site-packages\fastai\callback\core.py:72: UserWarning: You are shadowing an attribute (generator) that exists in the learner. Use `self.learn.generator` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# C:\Users\ritap\anaconda3\envs\fastaiv2\lib\site-packages\fastai\callback\core.py:72: UserWarning: You are shadowing an attribute (critic) that exists in the learner. Use `self.learn.critic` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# C:\Users\ritap\anaconda3\envs\fastaiv2\lib\site-packages\fastai\callback\core.py:72: UserWarning: You are shadowing an attribute (gen_mode) that exists in the learner. Use `self.learn.gen_mode` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>gen_loss</th>
#       <th>crit_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>-0.059839</td>
#       <td>0.194339</td>
#       <td>-0.266791</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>-0.105747</td>
#       <td>0.437949</td>
#       <td>-0.766571</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.063711</td>
#       <td>0.207493</td>
#       <td>-0.294158</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>-0.014767</td>
#       <td>0.432807</td>
#       <td>-0.376882</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>-0.044984</td>
#       <td>0.498825</td>
#       <td>-0.723457</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>-0.049450</td>
#       <td>0.426397</td>
#       <td>-0.544756</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>-0.106709</td>
#       <td>-0.379527</td>
#       <td>-0.037862</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>-0.068196</td>
#       <td>0.293872</td>
#       <td>-0.349017</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>-0.067198</td>
#       <td>0.518328</td>
#       <td>-0.684134</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>-0.058782</td>
#       <td>0.494198</td>
#       <td>-0.651671</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>-0.051229</td>
#       <td>0.443914</td>
#       <td>-0.567393</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>-0.048822</td>
#       <td>0.400802</td>
#       <td>-0.546884</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>-0.049616</td>
#       <td>0.386775</td>
#       <td>-0.514290</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>-0.051593</td>
#       <td>0.347701</td>
#       <td>-0.509941</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>-0.063932</td>
#       <td>0.351818</td>
#       <td>-0.543514</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>-0.068620</td>
#       <td>0.358794</td>
#       <td>-0.567082</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>-0.079058</td>
#       <td>0.407062</td>
#       <td>-0.660367</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>-0.099951</td>
#       <td>0.469726</td>
#       <td>-0.771020</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>-0.137845</td>
#       <td>0.503151</td>
#       <td>-0.969108</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>-0.143043</td>
#       <td>0.432006</td>
#       <td>-0.804929</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>-0.162352</td>
#       <td>0.522396</td>
#       <td>-0.972420</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>-0.170557</td>
#       <td>0.498477</td>
#       <td>-0.901596</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>-0.207556</td>
#       <td>0.621976</td>
#       <td>-1.226904</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>-0.217014</td>
#       <td>0.592202</td>
#       <td>-1.133863</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>-0.252151</td>
#       <td>0.605957</td>
#       <td>-1.309004</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\ritap\anaconda3\envs\fastaiv2\lib\site-packages\fastprogress\fastprogress.py:73: UserWarning: Your generator is empty.
#   warn("Your generator is empty.")

# %%
learn.show_results(max_n=4, ds_idx=0)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ### By looking at the above images, we can't say that they are anywhere close to house/ homes. However it is intutive that they are not random noise and the model is trying to generate some pattern where the top part is probably the sky, bottom part is ground and there is something in the middle.

# %% [markdown]
# ### Save the model

# %%
learn.export(r"..\..\models\GAN_model.pkl")

# %% [markdown]
# ## Let's generate images

# %%
# reading the model
model = load_learner(r"..\..\models\GAN_model.pkl")

# %%
# creating random noise
noise = generate_noise(fn=None, size=100)

# %%
# generating the image
pred_img = model.predict(noise)[0]
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
pred_img.shape
# Out:
# torch.Size([3, 64, 64])

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.imshow(np.transpose(pred_img))

# %%
plt.imshow(np.transpose(pred_img, [1, 2, 0]))
